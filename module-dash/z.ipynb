# %%
import pandas as pd

# %%
df = pd.read_csv('gapminder_edited.csv')
df
# Out:
#             country continent    year  lifeExp         pop     gdpPercap  \
# 0       Congo, Rep.    Africa  1987.0   57.470   2064095.0   4201.194937
# 1        Bangladesh      Asia  1982.0   50.009  93074406.0    676.981866
# 2           Algeria    Africa  1977.0   58.014  17152804.0   4910.416756
# 3            Malawi    Africa  1972.0   41.766   4730997.0    584.621971
# 4          Tanzania    Africa  1952.0   41.215   8322925.0    716.650072
# ...             ...       ...     ...      ...         ...           ...
# 1707  Guinea-Bissau    Africa  1957.0   33.489    601095.0    431.790457
# 1708         Turkey    Europe  1997.0   68.835  63047647.0   6601.429915
# 1709        Burundi    Africa  2002.0   47.360   7021078.0    446.403513
# 1710         Mexico  Americas  1977.0   65.032  63759976.0   7674.929108
# 1711         Kuwait      Asia  1982.0   71.309   1497494.0  31354.035730
#
#      iso_alpha  iso_num
# 0          COG    178.0
# 1          BGD     50.0
# 2          DZA     12.0
# 3          MWI    454.0
# 4          TZA    834.0
# ...        ...      ...
# 1707       GNB    624.0
# 1708       TUR    792.0
# 1709       BDI    108.0
# 1710       MEX    484.0
# 1711       KWT    414.0
#
# [1712 rows x 8 columns]

# %%
#  ON ne garde que les valeurs de l'année 2007
df = df[df['year'] == 2007]
df
# Out:
#           country continent    year  lifeExp         pop     gdpPercap  \
# 11      Singapore      Asia  2007.0   79.972   4553009.0  47143.179640
# 13    Philippines      Asia  2007.0   71.688  91077287.0   3190.481016
# 27       Thailand      Asia  2007.0   70.616  65068149.0   7458.396327
# 30           Iran      Asia  2007.0   70.964  69453570.0  11605.714490
# 54       Zimbabwe    Africa  2007.0   43.487  12311143.0    469.709298
# ...           ...       ...     ...      ...         ...           ...
# 1642      Burundi    Africa  2007.0   49.580   8390505.0    430.070692
# 1683       Poland    Europe  2007.0   75.563  38518241.0  15389.924680
# 1685    Mauritius    Africa  2007.0   72.801   1250882.0  10956.991120
# 1705      Lebanon      Asia  2007.0   71.993   3921278.0  10461.058680
# 1706        Egypt    Africa  2007.0   71.338  80264543.0   5581.180998
#
#      iso_alpha  iso_num
# 11         SGP    702.0
# 13         PHL    608.0
# 27         THA    764.0
# 30         IRN    364.0
# 54         ZWE    716.0
# ...        ...      ...
# 1642       BDI    108.0
# 1683       POL    616.0
# 1685       MUS    480.0
# 1705       LBN    422.0
# 1706       EGY    818.0
#
# [142 rows x 8 columns]

# %%
df = df.sort_values(by='pop', ascending=False)

# %%
import matplotlib.pyplot as plt
# histogram of pop by country

fig = plt.figure(figsize=(10, 6))
plt.bar(df['country'], df['pop'])
# rotation of country names
plt.xticks(rotation=90)
fig.show()
# Out:
# C:\Users\symph\AppData\Local\Temp\ipykernel_16548\3135469055.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
